# %%
from sympy import symbols, oo, Sum, pi, sin
from sympy.plotting import plot

# %%
x, y, i = symbols('x y i')
n = 1

# %%
f = Sum(4/pi*(sin((2*i-1)*x)/(2*i-1)), (i, 1, n))
f
# Out:
# Sum(4*sin(x*(2*i - 1))/(pi*(2*i - 1)), (i, 1, 1))

# %%
p = plot(f, (x, -2*pi, 2*pi))
p.show()
